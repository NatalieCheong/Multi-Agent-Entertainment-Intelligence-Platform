# %%
# !pip install -q mcp
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.9 MB/s eta 0:00:00

# %%
# !pip install -q openai

# %%
# !pip install -q fastmcp
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.2/138.2 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.0/240.0 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 5.1 MB/s eta 0:00:00

# %%
# !pip install -q pydantic

# %%
import os
import getpass

os.environ["OPENAI_API_KEY"] = getpass.getpass()
# Out:
# ··········

# %%
# 9. Test the system
print("🎬 Netflix MCP Application Setup Complete!")
print("=" * 50)
print("✅ You can now run:")
print("   • python mcp_application.py --test    # Run tests")
print("   • python mcp_application.py --info    # Show info")
print("   • python mcp_application.py --start   # Start app")
print("=" * 50)

# 10. Quick test to verify everything works
try:
    # Test imports
    import asyncio
    import nest_asyncio
    nest_asyncio.apply()

    # Test your existing modules
    from multi_agents_fastmcp import test_netflix_multi_agents
    from guardrail_fastmcp import test_guardrail_system

    print("✅ All imports successful!")
    print("🚀 Ready to run Netflix MCP Application in Google Colab!")

except ImportError as e:
    print(f"❌ Import error: {e}")
    print("📝 Make sure all files are uploaded to the correct directories")
# Out:
# 🎬 Netflix MCP Application Setup Complete!
# ==================================================
# ✅ You can now run:
#    • python mcp_application.py --test    # Run tests
#    • python mcp_application.py --info    # Show info
#    • python mcp_application.py --start   # Start app
# ==================================================
# ✅ All imports successful!
# 🚀 Ready to run Netflix MCP Application in Google Colab!

# %%
# In Google Colab - Test everything
# !python mcp_application.py --test
# !python mcp_application.py --info
# !python mcp_application.py --start
# Out:
# 🎬 Netflix MCP Application - Google Colab Compatible
# 🚀 Building an Application with MCP
# ============================================================
# Usage:
#   python mcp_application.py --start    # Start the application
#   python mcp_application.py --info     # Show application info
#   python mcp_application.py --config   # Generate Claude config
#   python mcp_application.py --test     # Run tests
# ============================================================
# ✅ Google Colab environment detected and configured
# 2025-06-20 00:56:39,445 - netflix-mcp-app - INFO - 🎬 Initializing Netflix Business Intelligence MCP
# 2025-06-20 00:56:39,445 - netflix-mcp-app - INFO - 💬 Setting up MCP Prompts...
# 2025-06-20 00:56:39,445 - netflix-mcp-app - INFO - ✅ 4 MCP Prompts configured
# 2025-06-20 00:56:39,445 - netflix-mcp-app - INFO - 📁 Setting up MCP Resources...
# 2025-06-20 00:56:39,446 - netflix-mcp-app - INFO - ✅ 5 MCP Resources configured
# 2025-06-20 00:56:39,446 - netflix-mcp-app - INFO - 🧪 Running Comprehensive MCP Application Test
# 2025-06-20 00:56:39,446 - netflix-mcp-app - INFO - ============================================================
# 2025-06-20 00:56:39,446 - netflix-mcp-app - INFO - 1️⃣ Testing MCP Server availability...
# 2025-06-20 00:56:39,446 - netflix-mcp-app - INFO -    ❌ FAILED
# 2025-06-20 00:56:39,446 - netflix-mcp-app - INFO - 2️⃣ Testing MCP Client initialization...
# 2025-06-20 00:56:39,446 - netflix-mcp-app - INFO -    ❌ FAILED
# 2025-06-20 00:56:39,446 - netflix-mcp-app - INFO - 3️⃣ Testing Prompts configuration...
# 2025-06-20 00:56:39,446 - netflix-mcp-app - INFO -    ✅ PASSED - 4 prompts loaded
# 2025-06-20 00:56:39,446 - netflix-mcp-app - INFO - 4️⃣ Testing Resources configuration...
# 2025-06-20 00:56:39,446 - netflix-mcp-app - INFO -    ✅ PASSED - 5 resources loaded
# 2025-06-20 00:56:39,446 - netflix-mcp-app - INFO - 5️⃣ Testing Dataset availability...
# 2025-06-20 00:56:39,446 - netflix-mcp-app - INFO -    ✅ PASSED
# 2025-06-20 00:56:39,446 - netflix-mcp-app - INFO - 6️⃣ Testing Business Intelligence...
# 2025-06-20 00:56:39,789 - numexpr.utils - INFO - NumExpr defaulting to 2 threads.
# ✅ MCP imports successful
# ✅ Multi-agents system loaded successfully
# ✅ Guardrail system loaded successfully
# 🔒 Netflix Content Guardrail System v2.0.0 initialized
# 2025-06-20 00:56:41,519 - netflix-mcp-server - INFO - Loading Netflix dataset...
# 2025-06-20 00:56:41,654 - netflix-mcp-server - INFO - Loaded 8807 titles from Netflix dataset
# 2025-06-20 00:56:41,693 - netflix-mcp-server - INFO - Data cleaning complete! Final dataset: 8807 titles
# 🎬 Netflix Multi-Agent System Processing: Test query
# 2025-06-20 00:56:42,955 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ✅ Multi-agent processing complete
# 2025-06-20 00:56:42,961 - netflix-mcp-server - INFO - Multi-agent insights obtained: 910 characters
# 🔒 Netflix Content Guardrail System v2.0.0 initialized
# 🔒 Running Netflix guardrail evaluation...
# --------------------------------------------------
# 2025-06-20 00:56:44,941 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 🔒 Safety Check: ✅ PASSED (Score: 0.90)
# 2025-06-20 00:56:46,665 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 📊 Quality Check: ✅ PASSED (Score: 0.80)
# 2025-06-20 00:56:48,392 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 💼 Business Check: ❌ FAILED (Score: 0.20)
# 2025-06-20 00:56:50,696 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 🌍 Bias Check: ❌ FAILED (Score: 0.30)
# --------------------------------------------------
# 🎯 Overall Score: 0.55
# 🚦 Passed All Guardrails: ❌ NO
# 2025-06-20 00:56:50,704 - netflix-mcp-app - INFO -    ✅ PASSED
# 2025-06-20 00:56:50,704 - netflix-mcp-app - INFO - 7️⃣ Testing Multi-Agent System...
# 2025-06-20 00:56:50,704 - netflix-mcp-app - INFO -    ✅ PASSED
# 2025-06-20 00:56:50,704 - netflix-mcp-app - INFO - 8️⃣ Testing Guardrail System...
# 2025-06-20 00:56:50,704 - netflix-mcp-app - INFO -    ✅ PASSED
# 2025-06-20 00:56:50,704 - netflix-mcp-app - INFO -
# 📊 Test Results: 6/8 passed (75.0%)
# 2025-06-20 00:56:50,704 - netflix-mcp-app - INFO -    ❌ FAILED: MCP Server
# 2025-06-20 00:56:50,704 - netflix-mcp-app - INFO -    ❌ FAILED: MCP Client
# 2025-06-20 00:56:50,704 - netflix-mcp-app - INFO -    ✅ PASSED: Prompts
# 2025-06-20 00:56:50,704 - netflix-mcp-app - INFO -    ✅ PASSED: Resources
# 2025-06-20 00:56:50,704 - netflix-mcp-app - INFO -    ✅ PASSED: Dataset
# 2025-06-20 00:56:50,704 - netflix-mcp-app - INFO -    ✅ PASSED: Business Intelligence
# 2025-06-20 00:56:50,704 - netflix-mcp-app - INFO -    ✅ PASSED: Multi-Agent System
# 2025-06-20 00:56:50,704 - netflix-mcp-app - INFO -    ✅ PASSED: Guardrail System
# 2025-06-20 00:56:50,704 - netflix-mcp-app - INFO - 👍 MOST TESTS PASSED! MCP Application is mostly operational!
# 🎬 Netflix MCP Application - Google Colab Compatible
# 🚀 Building an Application with MCP
# ============================================================
# Usage:
#   python mcp_application.py --start    # Start the application
#   python mcp_application.py --info     # Show application info
#   python mcp_application.py --config   # Generate Claude config
#   python mcp_application.py --test     # Run tests
# ============================================================
# ✅ Google Colab environment detected and configured
# 🎬 Netflix MCP Application Information
# ============================================================
# 📊 Features:
#    • Enhanced Business Intelligence with real Netflix data
#    • Multi-Agent system with 5 specialized agents
#    • Content safety and quality guardrails
#    • Personalized content recommendations
#    • Competitive analysis and market insights
#    • Interactive prompts and resource management
#    • Google Colab compatible
#    • Claude Desktop integration ready
#
# 🔧 Google Colab Setup:
#    • Upload all Python files to /content/
#    • Mount Google Drive for Netflix dataset
#    • Install dependencies: pip install mcp pandas numpy openai
#    • Run: python mcp_application.py --start
#
# 🤖 Available Agents:
#    • Content Discovery Agent - Find movies and shows
#    • Analytics Specialist Agent - Analyze trends and data
#    • Recommendation Engine Agent - Personalized suggestions
#    • Customer Support Agent - Help with Netflix features
#    • Content Strategy Agent - Business strategy insights
# ============================================================
# 🎬 Netflix MCP Application - Google Colab Compatible
# 🚀 Building an Application with MCP
# ============================================================
# Usage:
#   python mcp_application.py --start    # Start the application
#   python mcp_application.py --info     # Show application info
#   python mcp_application.py --config   # Generate Claude config
#   python mcp_application.py --test     # Run tests
# ============================================================
# ✅ Google Colab environment detected and configured
# 2025-06-20 00:56:51,478 - netflix-mcp-app - INFO - 🎬 Initializing Netflix Business Intelligence MCP
# 2025-06-20 00:56:51,478 - netflix-mcp-app - INFO - 🚀 Starting Netflix MCP Application...
# 2025-06-20 00:56:51,478 - netflix-mcp-app - INFO - ============================================================
# 2025-06-20 00:56:51,478 - netflix-mcp-app - INFO - 💬 Setting up MCP Prompts...
# 2025-06-20 00:56:51,478 - netflix-mcp-app - INFO - ✅ 4 MCP Prompts configured
# 2025-06-20 00:56:51,478 - netflix-mcp-app - INFO - 📁 Setting up MCP Resources...
# 2025-06-20 00:56:51,479 - netflix-mcp-app - INFO - ✅ 5 MCP Resources configured
# 2025-06-20 00:56:51,479 - netflix-mcp-app - INFO - 🔧 Initializing MCP Server...
# 2025-06-20 00:56:51,735 - numexpr.utils - INFO - NumExpr defaulting to 2 threads.
# ✅ MCP imports successful
# ✅ Multi-agents system loaded successfully
# ✅ Guardrail system loaded successfully
# 🔒 Netflix Content Guardrail System v2.0.0 initialized
# 2025-06-20 00:56:53,254 - netflix-mcp-server - INFO - Loading Netflix dataset...
# 2025-06-20 00:56:53,342 - netflix-mcp-server - INFO - Loaded 8807 titles from Netflix dataset
# 2025-06-20 00:56:53,377 - netflix-mcp-server - INFO - Data cleaning complete! Final dataset: 8807 titles
# 2025-06-20 00:56:53,378 - netflix-mcp-app - INFO - ✅ MCP Server module imported successfully
# 2025-06-20 00:56:53,378 - netflix-mcp-server - INFO - 🧪 Testing Netflix MCP Server functionality...
# 2025-06-20 00:56:53,378 - netflix-mcp-server - INFO - 🔍 Testing query: What percentage of Netflix content is Korean?
# 🎬 Netflix Multi-Agent System Processing: What percentage of Netflix content is Korean?
# 2025-06-20 00:56:55,218 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ✅ Multi-agent processing complete
# 2025-06-20 00:56:55,223 - netflix-mcp-server - INFO - Multi-agent insights obtained: 1057 characters
# 🔒 Netflix Content Guardrail System v2.0.0 initialized
# 🔒 Running Netflix guardrail evaluation...
# --------------------------------------------------
# 2025-06-20 00:56:56,591 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 🔒 Safety Check: ✅ PASSED (Score: 0.90)
# 2025-06-20 00:56:58,434 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 📊 Quality Check: ✅ PASSED (Score: 0.80)
# 2025-06-20 00:57:00,539 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 💼 Business Check: ✅ PASSED (Score: 0.80)
# 2025-06-20 00:57:02,125 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 🌍 Bias Check: ❌ FAILED (Score: 0.30)
# --------------------------------------------------
# 🎯 Overall Score: 0.70
# 🚦 Passed All Guardrails: ❌ NO
# 2025-06-20 00:57:02,126 - netflix-mcp-server - INFO - ✅ Result: success
# 2025-06-20 00:57:02,127 - netflix-mcp-server - INFO - 💡 Answer: 2.62% of Netflix content is Korean (231 out of 8807 titles)
# 2025-06-20 00:57:02,127 - netflix-mcp-server - INFO - 🔍 Testing query: What are the most popular genres globally?
# 🎬 Netflix Multi-Agent System Processing: What are the most popular genres globally?
# 2025-06-20 00:57:04,011 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ✅ Multi-agent processing complete
# 2025-06-20 00:57:04,012 - netflix-mcp-server - INFO - Multi-agent insights obtained: 1157 characters
# 🔒 Netflix Content Guardrail System v2.0.0 initialized
# 🔒 Running Netflix guardrail evaluation...
# --------------------------------------------------
# 2025-06-20 00:57:06,340 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 🔒 Safety Check: ✅ PASSED (Score: 0.90)
# 2025-06-20 00:57:10,899 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 📊 Quality Check: ✅ PASSED (Score: 0.80)
# 2025-06-20 00:57:12,738 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 💼 Business Check: ✅ PASSED (Score: 0.80)
# 2025-06-20 00:57:14,446 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 🌍 Bias Check: ❌ FAILED (Score: 0.30)
# --------------------------------------------------
# 🎯 Overall Score: 0.70
# 🚦 Passed All Guardrails: ❌ NO
# 2025-06-20 00:57:14,450 - netflix-mcp-server - INFO - ✅ Result: success
# 2025-06-20 00:57:14,450 - netflix-mcp-server - INFO - 💡 Answer: Most popular genre globally is 'International Movies' with 2752 titles (31.2%)
# 2025-06-20 00:57:14,450 - netflix-mcp-server - INFO - 🔍 Testing query: Show me the trend of international vs US content
# 🎬 Netflix Multi-Agent System Processing: Show me the trend of international vs US content
# 2025-06-20 00:57:21,588 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ✅ Multi-agent processing complete
# 2025-06-20 00:57:21,594 - netflix-mcp-server - INFO - Multi-agent insights obtained: 1904 characters
# 🔒 Netflix Content Guardrail System v2.0.0 initialized
# 🔒 Running Netflix guardrail evaluation...
# --------------------------------------------------
# 2025-06-20 00:57:23,842 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 🔒 Safety Check: ✅ PASSED (Score: 0.90)
# 2025-06-20 00:57:26,006 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 📊 Quality Check: ✅ PASSED (Score: 0.80)
# 2025-06-20 00:57:28,297 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 💼 Business Check: ✅ PASSED (Score: 0.80)
# 2025-06-20 00:57:28,699 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 🌍 Bias Check: ✅ PASSED (Score: 0.80)
# --------------------------------------------------
# 🎯 Overall Score: 0.82
# 🚦 Passed All Guardrails: ✅ YES
# 2025-06-20 00:57:28,700 - netflix-mcp-server - INFO - ✅ Result: success
# 2025-06-20 00:57:28,700 - netflix-mcp-server - INFO - 💡 Answer: International content represents 58.1% of Netflix catalog (5117 out of 8807 titles)
# 2025-06-20 00:57:28,700 - netflix-mcp-server - INFO - ✅ Standalone testing completed!
# 2025-06-20 00:57:28,700 - netflix-mcp-app - INFO - ✅ MCP Server initialized successfully
# 2025-06-20 00:57:28,701 - netflix-mcp-app - INFO - 🔧 Initializing MCP Client...
# 2025-06-20 00:57:28,706 - netflix-mcp-client - WARNING - ⚠️ MCP Client libraries not available: cannot import name 'StdioServerParameters' from 'mcp.client' (/usr/local/lib/python3.11/dist-packages/mcp/client/__init__.py)
# 2025-06-20 00:57:28,706 - netflix-mcp-client - INFO - 🔄 Will use fallback mock client for Google Colab
# 2025-06-20 00:57:28,706 - netflix-mcp-client - INFO - 🔄 Running in mock mode (Google Colab compatibility)
# 2025-06-20 00:57:28,706 - netflix-mcp-app - INFO - ✅ MCP Client initialized with mock mode for Google Colab
# 2025-06-20 00:57:28,706 - netflix-mcp-app - INFO - ✅ Netflix MCP Application started successfully!
# 2025-06-20 00:57:28,706 - netflix-mcp-app - INFO -
# 📊 Netflix MCP Application Status
# 2025-06-20 00:57:28,706 - netflix-mcp-app - INFO - ==================================================
# 2025-06-20 00:57:28,706 - netflix-mcp-app - INFO - 🔧 MCP Server: 🟢 Running
# 2025-06-20 00:57:28,706 - netflix-mcp-app - INFO - 💻 MCP Client: 🟢 Ready
# 2025-06-20 00:57:28,706 - netflix-mcp-app - INFO - 🔗 MCP Protocol: 🔴 Not Available (using fallback)
# 2025-06-20 00:57:28,707 - netflix-mcp-app - INFO - 🤖 Multi-Agents: 🟢 Enabled
# 2025-06-20 00:57:28,707 - netflix-mcp-app - INFO - 🔒 Guardrails: 🟢 Enabled
# 2025-06-20 00:57:28,707 - netflix-mcp-app - INFO - 💬 Prompts: 🟢 Loaded (4 available)
# 2025-06-20 00:57:28,707 - netflix-mcp-app - INFO - 📁 Resources: 🟢 Loaded (5 available)
# 2025-06-20 00:57:28,707 - netflix-mcp-app - INFO - 📊 Dataset: 🟢 Available
# 2025-06-20 00:57:28,707 - netflix-mcp-app - INFO -    Size: 3.2 MB
# 2025-06-20 00:57:28,708 - netflix-mcp-app - INFO - ==================================================
# 2025-06-20 00:57:28,708 - netflix-mcp-app - INFO -
# 🎮 Netflix MCP Application - Interactive Mode
# 2025-06-20 00:57:28,708 - netflix-mcp-app - INFO - ============================================================
# 2025-06-20 00:57:28,708 - netflix-mcp-app - INFO - Available features:
# 2025-06-20 00:57:28,708 - netflix-mcp-app - INFO -   1. Test Business Intelligence Query
# 2025-06-20 00:57:28,708 - netflix-mcp-app - INFO -   2. Test Multi-Agent System (if available)
# 2025-06-20 00:57:28,708 - netflix-mcp-app - INFO -   3. Test Guardrail System (if available)
# 2025-06-20 00:57:28,708 - netflix-mcp-app - INFO -   4. View Available Prompts
# 2025-06-20 00:57:28,708 - netflix-mcp-app - INFO -   5. View Available Resources
# 2025-06-20 00:57:28,708 - netflix-mcp-app - INFO -   6. System Status
# 2025-06-20 00:57:28,708 - netflix-mcp-app - INFO -   7. Run Comprehensive Test
# 2025-06-20 00:57:28,708 - netflix-mcp-app - INFO -   8. Test Netflix Dataset Analysis
# 2025-06-20 00:57:28,708 - netflix-mcp-app - INFO -   9. Generate Sample Queries
# 2025-06-20 00:57:28,708 - netflix-mcp-app - INFO -   10. Exit Application
# 2025-06-20 00:57:28,708 - netflix-mcp-app - INFO - ============================================================
#
# 🎯 Select option (1-10): 9
# 2025-06-20 00:58:06,629 - netflix-mcp-app - INFO - 📝 Sample Netflix MCP Queries
# 2025-06-20 00:58:06,630 - netflix-mcp-app - INFO - ========================================
# 2025-06-20 00:58:06,630 - netflix-mcp-app - INFO -  1. What percentage of Netflix content is Korean?
# 2025-06-20 00:58:06,630 - netflix-mcp-app - INFO -  2. What are the most popular genres globally?
# 2025-06-20 00:58:06,630 - netflix-mcp-app - INFO -  3. Show me the trend of international vs US content
# 2025-06-20 00:58:06,630 - netflix-mcp-app - INFO -  4. How many thriller movies does Netflix have?
# 2025-06-20 00:58:06,630 - netflix-mcp-app - INFO -  5. What countries produce the most Netflix content?
# 2025-06-20 00:58:06,630 - netflix-mcp-app - INFO -  6. What's the distribution of content by release year?
# 2025-06-20 00:58:06,630 - netflix-mcp-app - INFO -  7. Which directors have the most titles on Netflix?
# 2025-06-20 00:58:06,630 - netflix-mcp-app - INFO -  8. What's the average duration of Netflix movies?
# 2025-06-20 00:58:06,630 - netflix-mcp-app - INFO -  9. How much kids content does Netflix have?
# 2025-06-20 00:58:06,630 - netflix-mcp-app - INFO - 10. What are the trending genres in 2023?
# 2025-06-20 00:58:06,630 - netflix-mcp-app - INFO -
# 💡 You can use these queries to test the business intelligence system!
#
# 🎯 Select option (1-10): 8
# 2025-06-20 00:58:25,895 - netflix-mcp-app - INFO - 📊 Testing Netflix Dataset Analysis...
# 2025-06-20 00:58:25,896 - netflix-mcp-app - INFO - 📁 Loading dataset...
# 2025-06-20 00:58:25,980 - netflix-mcp-app - INFO - ✅ Dataset loaded successfully!
# 2025-06-20 00:58:25,980 - netflix-mcp-app - INFO - 📊 Dataset Statistics:
# 2025-06-20 00:58:25,980 - netflix-mcp-app - INFO -    Total titles: 8807
# 2025-06-20 00:58:25,983 - netflix-mcp-app - INFO -    Movies: 6131
# 2025-06-20 00:58:25,986 - netflix-mcp-app - INFO -    TV Shows: 2676
# 2025-06-20 00:58:25,991 - netflix-mcp-app - INFO -    Top 5 countries: ['United States', 'India', 'United Kingdom', 'Japan', 'South Korea']
# 2025-06-20 00:58:26,009 - netflix-mcp-app - INFO -    Top 5 genres: ['International Movies', 'Dramas', 'Comedies', 'International TV Shows', 'Documentaries']
#
# 🎯 Select option (1-10): 9
# 2025-06-20 00:58:45,364 - netflix-mcp-app - INFO - 📝 Sample Netflix MCP Queries
# 2025-06-20 00:58:45,364 - netflix-mcp-app - INFO - ========================================
# 2025-06-20 00:58:45,364 - netflix-mcp-app - INFO -  1. What percentage of Netflix content is Korean?
# 2025-06-20 00:58:45,364 - netflix-mcp-app - INFO -  2. What are the most popular genres globally?
# 2025-06-20 00:58:45,364 - netflix-mcp-app - INFO -  3. Show me the trend of international vs US content
# 2025-06-20 00:58:45,364 - netflix-mcp-app - INFO -  4. How many thriller movies does Netflix have?
# 2025-06-20 00:58:45,364 - netflix-mcp-app - INFO -  5. What countries produce the most Netflix content?
# 2025-06-20 00:58:45,364 - netflix-mcp-app - INFO -  6. What's the distribution of content by release year?
# 2025-06-20 00:58:45,364 - netflix-mcp-app - INFO -  7. Which directors have the most titles on Netflix?
# 2025-06-20 00:58:45,364 - netflix-mcp-app - INFO -  8. What's the average duration of Netflix movies?
# 2025-06-20 00:58:45,364 - netflix-mcp-app - INFO -  9. How much kids content does Netflix have?
# 2025-06-20 00:58:45,364 - netflix-mcp-app - INFO - 10. What are the trending genres in 2023?
# 2025-06-20 00:58:45,364 - netflix-mcp-app - INFO -
# 💡 You can use these queries to test the business intelligence system!
#
# 🎯 Select option (1-10): 9
# 2025-06-20 00:58:57,606 - netflix-mcp-app - INFO - 📝 Sample Netflix MCP Queries
# 2025-06-20 00:58:57,607 - netflix-mcp-app - INFO - ========================================
# 2025-06-20 00:58:57,607 - netflix-mcp-app - INFO -  1. What percentage of Netflix content is Korean?
# 2025-06-20 00:58:57,607 - netflix-mcp-app - INFO -  2. What are the most popular genres globally?
# 2025-06-20 00:58:57,607 - netflix-mcp-app - INFO -  3. Show me the trend of international vs US content
# 2025-06-20 00:58:57,607 - netflix-mcp-app - INFO -  4. How many thriller movies does Netflix have?
# 2025-06-20 00:58:57,607 - netflix-mcp-app - INFO -  5. What countries produce the most Netflix content?
# 2025-06-20 00:58:57,607 - netflix-mcp-app - INFO -  6. What's the distribution of content by release year?
# 2025-06-20 00:58:57,607 - netflix-mcp-app - INFO -  7. Which directors have the most titles on Netflix?
# 2025-06-20 00:58:57,607 - netflix-mcp-app - INFO -  8. What's the average duration of Netflix movies?
# 2025-06-20 00:58:57,607 - netflix-mcp-app - INFO -  9. How much kids content does Netflix have?
# 2025-06-20 00:58:57,607 - netflix-mcp-app - INFO - 10. What are the trending genres in 2023?
# 2025-06-20 00:58:57,607 - netflix-mcp-app - INFO -
# 💡 You can use these queries to test the business intelligence system!
#
# 🎯 Select option (1-10): 2
# 2025-06-20 00:59:07,640 - netflix-mcp-app - INFO - 🤖 Testing Multi-Agent System...
# 2025-06-20 00:59:07,641 - netflix-mcp-app - INFO - 🔍 Running multi-agent system test...
# 🎬 Testing Netflix Multi-Agent System (FastMCP Version)
# ============================================================
#
# 🧪 Test 1: I'm looking for action movies with good ratings
# ----------------------------------------
# 🎬 Netflix Multi-Agent System Processing: I'm looking for action movies with good ratings
# 2025-06-20 00:59:20,993 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ✅ Multi-agent processing complete
# ✅ Result: Great! Action movies can be thrilling and entertaining. Here are some highly-rated action movies that I think you'll enjoy:
#
# 1. **Mad Max: Fury Road (2015)**
#    - **Rating:** 8.1/10
#    - **Plot Summar...
#
# 🧪 Test 2: What are the latest trends in thriller content?
# ----------------------------------------
# 🎬 Netflix Multi-Agent System Processing: What are the latest trends in thriller content?
# 10
# 2025-06-20 00:59:31,817 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ✅ Multi-agent processing complete
# ✅ Result: As of October 2023, the thriller genre continues to captivate audiences globally, with notable trends reflecting viewer preferences and the evolving landscape of content consumption. Here’s a comprehe...
#
# 🧪 Test 3: Recommend some Korean dramas for me
# ----------------------------------------
# 🎬 Netflix Multi-Agent System Processing: Recommend some Korean dramas for me
# 2025-06-20 00:59:33,928 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ✅ Multi-agent processing complete
# ✅ Result: To tailor my recommendations, could you please share a bit more about your preferences? For example, do you enjoy romantic comedies, thrillers, historical dramas, or fantasy? Additionally, are there a...
#
# 🧪 Test 4: What are Netflix subscription plans?
# ----------------------------------------
# 🎬 Netflix Multi-Agent System Processing: What are Netflix subscription plans?
# 2025-06-20 00:59:41,206 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ✅ Multi-agent processing complete
# ✅ Result: Netflix offers a variety of subscription plans to cater to different viewing preferences and needs. As of October 2023, here are the main plans available:
#
# 1. **Basic Plan**:
#    - Price: Lowest tier
#  ...
#
# 🧪 Test 5: What content should Netflix focus on for international markets?
# ----------------------------------------
# 🎬 Netflix Multi-Agent System Processing: What content should Netflix focus on for international markets?
# 2025-06-20 00:59:53,551 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ✅ Multi-agent processing complete
# ✅ Result: To make informed content acquisition and production decisions for international markets, Netflix should focus on several key strategies grounded in market trends, audience behavior, and competitive an...
#
# ✅ Netflix Multi-Agent System Test Complete!
# 2025-06-20 00:59:53,553 - netflix-mcp-app - INFO - ✅ Multi-agent system test completed!
#
# 🎯 Select option (1-10): 2025-06-20 00:59:53,553 - netflix-mcp-app - INFO - 👋 Shutting down Netflix MCP Application...
